# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
raw_data = pd.read_csv('datasets/Iris.csv')

# %%
data = raw_data.copy()

# %%
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# # Scatter Plot
# ### Creating a Scatter Plot Chart to better understand the relationships between different pairs of features from the species

# %%
sns.set_style('white')
plt.figure(figsize = (12, 6))
plt.scatter(data['Species'],
           data['SepalLengthCm'],
           color = 'midnightblue')
plt.title('Iris Species by Sepal Length', fontsize = 14, weight = 'bold')
plt.xlabel('Species', weight = 'bold')
plt.ylabel('Sepal Length in Cm', weight = 'bold')
plt.show()

# %% [markdown]
# #### The table above represents the different Iris Species by their respective Sepal Length in Cm

# %%
sns.set_style('white')
plt.figure(figsize = (12, 6))
plt.scatter(data['Species'],
           data['SepalWidthCm'],
           color = 'midnightblue')
plt.title('Iris Species by Sepal Width', fontsize = 14, weight = 'bold')
plt.xlabel('Species', weight = 'bold')
plt.ylabel('Sepal Width in Cm', weight = 'bold')
plt.show()

# %% [markdown]
# #### The table above represents the different Iris Species by their respective Sepal Width in Cm

# %%
sns.set_style('white')
plt.figure(figsize = (12, 6))
plt.scatter(data['Species'],
           data['PetalLengthCm'],
           color = 'midnightblue')
plt.title('Iris Species by Petal Length', fontsize = 14, weight = 'bold')
plt.xlabel('Species', weight = 'bold')
plt.ylabel('Petal Length in Cm', weight = 'bold')
plt.show()

# %% [markdown]
# #### The table above represents the different Iris Species by their respective Petal Length in Cm

# %%
sns.set_style('white')
plt.figure(figsize = (12, 6))
plt.scatter(data['Species'],
           data['PetalWidthCm'],
           color = 'midnightblue')
plt.title('Iris Species by Petal Width', fontsize = 14, weight = 'bold')
plt.xlabel('Species', weight = 'bold')
plt.ylabel('Petal Width in Cm', weight = 'bold')
plt.show()

# %% [markdown]
# #### The table above represents the different Iris Species by their respective Petal Width in Cm

# %% [markdown]
# # Histogram of the Iris Species

# %%
plt.figure(figsize = (12,8))
for i in ['SepalLengthCm']:
    plt.hist([data[i][data['Species'] == 'Iris-setosa'],
             data[i][data['Species'] == 'Iris-versicolor'],
             data[i][data['Species'] == 'Iris-virginica']],
            bins = 10,
             alpha = 0.6,
            label = ['Setosa', 'Versicolor', 'Virginica'])
plt.ylabel('Frequency', weight = 'bold')
plt.xlabel('Sepal Length (Cm)', weight = 'bold')
plt.title('Distribution of Sepal Length in Cm', fontsize = 16, weight = 'bold')
plt.legend(loc = 'upper right')
plt.show()

# %% [markdown]
# #### Table above represents the frequency of the different Iris species based on their Sepal Length

# %%
plt.figure(figsize = (12,8))
for i in ['SepalWidthCm']:
    plt.hist([data[i][data['Species'] == 'Iris-setosa'],
             data[i][data['Species'] == 'Iris-versicolor'],
             data[i][data['Species'] == 'Iris-virginica']],
            bins = 10,
             alpha = 0.6,
            label = ['Setosa', 'Versicolor', 'Virginica'])
plt.ylabel('Frequency', weight = 'bold')
plt.xlabel('Sepal Width (Cm)', weight = 'bold')
plt.title('Distribution of Sepal Width in Cm', fontsize = 16, weight = 'bold')
plt.legend(loc = 'upper right')
plt.show()

# %% [markdown]
# #### Table above represents the frequency of the different Iris species based on their Sepal Width

# %%
plt.figure(figsize = (12,8))
for i in ['PetalLengthCm']:
    plt.hist([data[i][data['Species'] == 'Iris-setosa'],
             data[i][data['Species'] == 'Iris-versicolor'],
             data[i][data['Species'] == 'Iris-virginica']],
            bins = 10,
             alpha = 0.6,
            label = ['Setosa', 'Versicolor', 'Virginica'])
plt.ylabel('Frequency', weight = 'bold')
plt.xlabel('Petal Length (Cm)', weight = 'bold')
plt.title('Distribution of Petal Length in Cm', fontsize = 16, weight = 'bold')
plt.legend(loc = 'upper right')
plt.show()

# %% [markdown]
# #### Table above represents the frequency of the different Iris species based on their Petal Length

# %%
plt.figure(figsize = (12,8))
for i in ['PetalWidthCm']:
    plt.hist([data[i][data['Species'] == 'Iris-setosa'],
             data[i][data['Species'] == 'Iris-versicolor'],
             data[i][data['Species'] == 'Iris-virginica']],
            bins = 10,
             alpha = 0.6,
            label = ['Setosa', 'Versicolor', 'Virginica'])
plt.ylabel('Frequency', weight = 'bold')
plt.xlabel('Petal Length (Cm)', weight = 'bold')
plt.title('Distribution of Petal Width in Cm', fontsize = 16, weight = 'bold')
plt.legend(loc = 'upper right')
plt.show()

# %% [markdown]
# #### Table above represents the frequency of the different Iris species based on their Petal Length

# %% [markdown]
# # Statistical Summary

# %% [markdown]
# ### Statistical Summary by the Length

# %%
length_feature = ['SepalLengthCm', 'PetalLengthCm']

for i in length_feature:
    mean = np.mean(data[i])
    median = np.median(data[i])
    std = np.std(data[i])
    str_strip = i.strip('Cm')
    
    print(str_strip)
    print(f"Mean: {mean:.2f}")
    print(f"Median: {median:.2f}")
    print(f"Standard Deviation: {std:.2f}")
    print("-" * 30)
# Out:
# SepalLength
# Mean: 5.84
# Median: 5.80
# Standard Deviation: 0.83
# ------------------------------
# PetalLength
# Mean: 3.76
# Median: 4.35
# Standard Deviation: 1.76
# ------------------------------

# %% [markdown]
#  ##### from the calcuation it shows that the average of sepal length for the species is 5.84 while the median sepal length is 5.80, and the standard deviation is dispersed not too high or too low from the mean. In the other hand, the average of petal length for the three species is 3.76, median petal length is 4.35, however, the standard deviation is dispersed slightly greater from the mean value.

# %% [markdown]
# ### Statistical Summary by the Width

# %%
width_feature = ['SepalWidthCm', 'PetalWidthCm']

for i in width_feature:
    mean = np.mean(data[i])
    median = np.median(data[i])
    std = np.std(data[i])
    str_strip = i.strip('Cm')
    
    print(str_strip)
    print(f"Mean: {mean:.2f}")
    print(f"Median: {median:.2f}")
    print(f"Standard Deviation: {std:.2f}")
    print("-" * 30)
# Out:
# SepalWidth
# Mean: 3.05
# Median: 3.00
# Standard Deviation: 0.43
# ------------------------------
# PetalWidth
# Mean: 1.20
# Median: 1.30
# Standard Deviation: 0.76
# ------------------------------

# %% [markdown]
# ##### from the calcuation it shows that the average of sepal width for the species is 3.05 while the median sepal width is 3.00, and the standard deviation is fairly dispersed from the mean value. In the other hand, the average of petal width for the three species is 1.20, median petal width is 1.30, however, the standard deviation is dispersed close around the mean value.

# %% [markdown]
# # Feature Relationship

# %%
#Drop Id from the DataFrame

dropped_id = data.drop('Id', axis = 1)

# %%
dropped_id
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(data = dropped_id, hue = 'Species')
plt.show()

# %% [markdown]
# ##### The relationship between Sepal Length and Petal Length is that species with short Sepal length would also have short Petal length.
# ##### The relationship between Sepal Length and Sepal Width shows that shorter Sepal Length tends to have wider Sepal Width.
# ##### The relationship between Sepal Length and Petal Width shows that longer Sepal Length would also have smaller Petal Width, while longer Sepal Length would have wider Petal Width.
# ##### The relationship between Petal Length and Petal Width shows that species with longer Petal length most likely would have wider Petal in width.
# ##### The relationship between Petal Length and Sepal Width shows that species long Petal would have smaller Sepal for the most parts.
# ##### The relationship between Petal Width and Sepal Width shows wider Petal will have smaller Sepal, for the most parts.

# %% [markdown]
# # Class Distribution

# %%
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
plt.figure(figsize = (9,6))

sns.countplot(data = data, x = 'Species')
plt.title('Class Distribution of Iris Species', fontsize = 16, weight = 'bold')
plt.ylabel('Count', weight = 'bold')
plt.xlabel('Species', weight = 'bold')
plt.show()

# %% [markdown]
# ##### The chart above represents that all three species count is 50, therefore, there are not any imbalance in data rather the data is evenly represented.

# %% [markdown]
# # Summary

# %% [markdown]
# #### All three Iris species count up to 50, there are no imbalance in the data, rather the data is evenly represented. Now, if we have to drill down to each species individually; the characteristic for Iris Setosa, they have short and small in terms of the Sepal length, Petal length and Petal width, but large Sepal width; the characteristic for Iris Versicolor, they have medium Sepal length, Petal length, and Petal width, but small Sepal width; and, the charactersitic for Iris Virginica, they have long and wide Sepal length, Petal length, and Petal width, but medium Sepal width. As for the statistical calculation of the data, it shows that for all the species the average Sepal length is 5.84 with standard devation around 0.83, and median of 5.80; the average Petal length is 3.76 with standard deviation of 1.76, meaning that the Sepal length of all species are almost similar, however, the Petal length of all species are more spread apart. On the other hand, the Sepal Width and Petal Width are almost even, the average Sepal width is 3.05 with standard deviation of 0.43, and median of 3.00; the average Petal width is 1.20 with standard deviation of 0.76, and median of 1.30. As you can see, to compare the standard deviation for the width is not too dramatic compared to the standard deviation for the length. In term of the relation, Longer Sepal would have smaller Sepal width, but would have longer and wider Petal. In the other hand, Iris species with longer Petal would have smaller Sepal width, but would have long Sepal length and wider Petal width.
